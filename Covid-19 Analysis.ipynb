# %% [markdown]
# # Dynamic visualization of COVID-19 data

# %% [markdown]
# ### Weekly trend of COVID-19 in US

# %%
library(tidyverse)
library(readr)

# %%
# filename <- readr_example("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/03-13-2021.csv")
# read_csv(filename, col_types = cols())
data_1 <- read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/03-13-2021.csv",col_types = cols())
data_2 <- read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/03-14-2021.csv",col_types = cols())
data_3 <- read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/03-15-2021.csv",col_types = cols())
data_4 <- read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/03-16-2021.csv",col_types = cols())
data_5 <- read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/03-17-2021.csv",col_types = cols())
data_6 <- read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/03-18-2021.csv",col_types = cols())
data_7 <- read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/03-19-2021.csv",col_types = cols())
data_1_2 <- rbind(data_1, data_2)
data_3_4 <- rbind(data_3, data_4)
data_5_6 <- rbind(data_5, data_6)
data_1half <- rbind(data_1_2, data_3_4)
data_2half <- rbind(data_5_6, data_7)
covid_data <- rbind(data_1half, data_2half)
glimpse(covid_data)
# Out:
# Observations: 406
# Variables: 18
# $ Province_State       <chr> "Alabama", "Alaska", "American Samoa", "Arizon...
# $ Country_Region       <chr> "US", "US", "US", "US", "US", "US", "US", "US"...
# $ Last_Update          <dttm> 2021-03-14 05:31:09, 2021-03-14 05:31:09, 202...
# $ Lat                  <dbl> 32.3182, 61.3707, -14.2710, 33.7298, 34.9697, ...
# $ Long_                <dbl> -86.9023, -152.4044, -170.1320, -111.4312, -92...
# $ Confirmed            <dbl> 503305, 60207, 0, 832094, 326813, 3620890, 442...
# $ Deaths               <dbl> 10327, 306, 0, 16546, 5455, 56426, 6036, 7765,...
# $ Recovered            <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA...
# $ Active               <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA...
# $ FIPS                 <dbl> 1, 2, 60, 4, 5, 6, 8, 9, 10, 88888, 11, 12, 13...
# $ Incident_Rate        <dbl> 10264.858, 8230.116, 0.000, 11431.877, 10829.4...
# ...

# %%
covid_data
# Out:
#     Province_State           Country_Region Last_Update         Lat
# 1   Alabama                  US             2021-03-14 05:31:09  32.3182
# 2   Alaska                   US             2021-03-14 05:31:09  61.3707
# 3   American Samoa           US             2021-03-14 05:31:09 -14.2710
# 4   Arizona                  US             2021-03-14 05:31:09  33.7298
# 5   Arkansas                 US             2021-03-14 05:31:09  34.9697
# 6   California               US             2021-03-14 08:30:48  36.1162
# 7   Colorado                 US             2021-03-14 05:31:09  39.0598
# 8   Connecticut              US             2021-03-14 05:31:09  41.5978
# 9   Delaware                 US             2021-03-14 05:31:09  39.3185
# 10  Diamond Princess         US             2021-03-14 05:31:09       NA
# 11  District of Columbia     US             2021-03-14 05:31:09  38.8974
# 12  Florida                  US             2021-03-14 05:31:09  27.7663
# ...

# %%
data_east_coast_day_1<-covid_data %>% filter(Last_Update<= "2021-03-14 05:31:09",Province_State == "Florida"|Province_State == "Georgia"|Province_State == "South Carolina"|Province_State == "North Carolina"|Province_State == "Virginia"|Province_State == "Maryland"|Province_State == "Delaware"|Province_State == "New Jersey"|Province_State == "Connecticut"|Province_State == "Massachusetts"|Province_State == "New Hampshire"|Province_State == "Maine"|Province_State == "New York"|Province_State == "Rhode Island")
data_east_coast_day_2<-covid_data %>% filter(Last_Update>= "2021-03-14 05:31:09",Last_Update<"2021-03-15 05:31:06",Province_State == "Florida"|Province_State == "Georgia"|Province_State == "South Carolina"|Province_State == "North Carolina"|Province_State == "Virginia"|Province_State == "Maryland"|Province_State == "Delaware"|Province_State == "New Jersey"|Province_State == "Connecticut"|Province_State == "Massachusetts"|Province_State == "New Hampshire"|Province_State == "Maine"|Province_State == "New York"|Province_State == "Rhode Island")
data_east_coast_day_3<-covid_data %>% filter(Last_Update>= "2021-03-15 05:31:06",Last_Update<"2021-03-16 05:31:04",Province_State == "Florida"|Province_State == "Georgia"|Province_State == "South Carolina"|Province_State == "North Carolina"|Province_State == "Virginia"|Province_State == "Maryland"|Province_State == "Delaware"|Province_State == "New Jersey"|Province_State == "Connecticut"|Province_State == "Massachusetts"|Province_State == "New Hampshire"|Province_State == "Maine"|Province_State == "New York"|Province_State == "Rhode Island")
data_east_coast_day_4<-covid_data %>% filter(Last_Update>= "2021-03-16 05:31:04",Last_Update<"2021-03-17 05:31:00",Province_State == "Florida"|Province_State == "Georgia"|Province_State == "South Carolina"|Province_State == "North Carolina"|Province_State == "Virginia"|Province_State == "Maryland"|Province_State == "Delaware"|Province_State == "New Jersey"|Province_State == "Connecticut"|Province_State == "Massachusetts"|Province_State == "New Hampshire"|Province_State == "Maine"|Province_State == "New York"|Province_State == "Rhode Island")
data_east_coast_day_5<-covid_data %>% filter(Last_Update>= "2021-03-17 05:31:00",Last_Update<"2021-03-18 05:31:01",Province_State == "Florida"|Province_State == "Georgia"|Province_State == "South Carolina"|Province_State == "North Carolina"|Province_State == "Virginia"|Province_State == "Maryland"|Province_State == "Delaware"|Province_State == "New Jersey"|Province_State == "Connecticut"|Province_State == "Massachusetts"|Province_State == "New Hampshire"|Province_State == "Maine"|Province_State == "New York"|Province_State == "Rhode Island")
data_east_coast_day_6<-covid_data %>% filter(Last_Update>= "2021-03-18 05:31:01",Last_Update<"2021-03-19 05:30:59",Province_State == "Florida"|Province_State == "Georgia"|Province_State == "South Carolina"|Province_State == "North Carolina"|Province_State == "Virginia"|Province_State == "Maryland"|Province_State == "Delaware"|Province_State == "New Jersey"|Province_State == "Connecticut"|Province_State == "Massachusetts"|Province_State == "New Hampshire"|Province_State == "Maine"|Province_State == "New York"|Province_State == "Rhode Island")
data_east_coast_day_7<-covid_data %>% filter(Last_Update>= "2021-03-19 05:30:59",Last_Update<"2021-03-20 05:31:09",Province_State == "Florida"|Province_State == "Georgia"|Province_State == "South Carolina"|Province_State == "North Carolina"|Province_State == "Virginia"|Province_State == "Maryland"|Province_State == "Delaware"|Province_State == "New Jersey"|Province_State == "Connecticut"|Province_State == "Massachusetts"|Province_State == "New Hampshire"|Province_State == "Maine"|Province_State == "New York"|Province_State == "Rhode Island")
data_east_day_1_2 <- rbind(data_east_coast_day_1, data_east_coast_day_2)
data_east_day_3_4 <- rbind(data_east_coast_day_3, data_east_coast_day_4)
data_east_day_5_6 <- rbind(data_east_coast_day_5, data_east_coast_day_6)
data_east_day_1half <- rbind(data_east_day_1_2, data_east_day_3_4)
data_east_day_2half <- rbind(data_east_day_5_6, data_east_coast_day_7)
covid_data_east <- rbind(data_east_day_1half, data_east_day_2half)
glimpse(covid_data_east)

covid_data_east
# Out:
# Observations: 98
# Variables: 18
# $ Province_State       <chr> "Connecticut", "Delaware", "Florida", "Georgia...
# $ Country_Region       <chr> "US", "US", "US", "US", "US", "US", "US", "US"...
# $ Last_Update          <dttm> 2021-03-14 05:31:09, 2021-03-14 05:31:09, 202...
# $ Lat                  <dbl> 41.5978, 39.3185, 27.7663, 33.0406, 44.6939, 3...
# $ Long_                <dbl> -72.7554, -75.5071, -81.6868, -83.6431, -69.38...
# $ Confirmed            <dbl> 290577, 90156, 1973109, 1032967, 46863, 392581...
# $ Deaths               <dbl> 7765, 1504, 32225, 18216, 724, 8038, 16614, 11...
# $ Recovered            <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA...
# $ Active               <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA...
# $ FIPS                 <dbl> 9, 10, 12, 13, 23, 24, 25, 33, 34, 36, 37, 44,...
# $ Incident_Rate        <dbl> 8150.171, 9258.506, 9186.764, 9728.980, 3486.2...
# ...

# %%
data_west_coast_day_1<-covid_data %>% filter(Last_Update<= "2021-03-14 05:31:09",Province_State == "Alaska"|Province_State == "California"|Province_State == "Hawaii"|Province_State == "Oregon"|Province_State == "Washington")
data_west_coast_day_2<-covid_data %>% filter(Last_Update>= "2021-03-14 05:31:09",Last_Update<"2021-03-15 05:31:06",Province_State == "Alaska"|Province_State == "California"|Province_State == "Hawaii"|Province_State == "Oregon"|Province_State == "Washington")
data_west_coast_day_3<-covid_data %>% filter(Last_Update>= "2021-03-15 05:31:06",Last_Update<"2021-03-16 05:31:04",Province_State == "Alaska"|Province_State == "California"|Province_State == "Hawaii"|Province_State == "Oregon"|Province_State == "Washington")
data_west_coast_day_4<-covid_data %>% filter(Last_Update>= "2021-03-16 05:31:04",Last_Update<"2021-03-17 05:31:00",Province_State == "Alaska"|Province_State == "California"|Province_State == "Hawaii"|Province_State == "Oregon"|Province_State == "Washington")
data_west_coast_day_5<-covid_data %>% filter(Last_Update>= "2021-03-17 05:31:00",Last_Update<"2021-03-18 05:31:01",Province_State == "Alaska"|Province_State == "California"|Province_State == "Hawaii"|Province_State == "Oregon"|Province_State == "Washington")
data_west_coast_day_6<-covid_data %>% filter(Last_Update>= "2021-03-18 05:31:01",Last_Update<"2021-03-19 05:30:59",Province_State == "Alaska"|Province_State == "California"|Province_State == "Hawaii"|Province_State == "Oregon"|Province_State == "Washington")
data_west_coast_day_7<-covid_data %>% filter(Last_Update>= "2021-03-19 05:30:59",Last_Update<"2021-03-20 05:31:09",Province_State == "Alaska"|Province_State == "California"|Province_State == "Hawaii"|Province_State == "Oregon"|Province_State == "Washington")
data_west_day_1_2 <- rbind(data_west_coast_day_1, data_west_coast_day_2)
data_west_day_3_4 <- rbind(data_west_coast_day_3, data_west_coast_day_4)
data_west_day_5_6 <- rbind(data_west_coast_day_5, data_west_coast_day_6)
data_west_day_1half <- rbind(data_west_day_1_2, data_west_day_3_4)
data_west_day_2half <- rbind(data_west_day_5_6, data_west_coast_day_7)
covid_data_west <- rbind(data_west_day_1half, data_west_day_2half)
glimpse(covid_data_west)

covid_data_west
# Out:
# Observations: 35
# Variables: 18
# $ Province_State       <chr> "Alaska", "California", "Hawaii", "Oregon", "W...
# $ Country_Region       <chr> "US", "US", "US", "US", "US", "US", "US", "US"...
# $ Last_Update          <dttm> 2021-03-14 05:31:09, 2021-03-14 08:30:48, 202...
# $ Lat                  <dbl> 61.3707, 36.1162, 21.0943, 44.5720, 47.4009, 6...
# $ Long_                <dbl> -152.4044, -119.6816, -157.4983, -122.0709, -1...
# $ Confirmed            <dbl> 60207, 3620890, 28504, 159402, 349425, 60207, ...
# $ Deaths               <dbl> 306, 56426, 449, 2322, 5123, 306, 56573, 450, ...
# $ Recovered            <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA...
# $ Active               <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA...
# $ FIPS                 <dbl> 2, 6, 15, 41, 53, 2, 6, 15, 41, 53, 2, 6, 15, ...
# $ Incident_Rate        <dbl> 8230.116, 9163.974, 2013.176, 3779.325, 4588.7...
# ...

# %%
data_mid_coast_day_1<-covid_data %>% filter(Last_Update<= "2021-03-14 05:31:09",Province_State == "Arizona"|Province_State == "Arkansas"|Province_State == "Colorado"|Province_State == "Diamond Princess"|Province_State == "District of Columbia"|Province_State == "Grand Princess"|Province_State == "Guam"|Province_State == "Idaho"|Province_State == "Illinois"|Province_State == "Indiana"|Province_State == "Iowa"|Province_State == "Kansas"|Province_State == "Kentucky"|Province_State == "Louisiana"|Province_State == "Michigan"|Province_State == "Minnesota"|Province_State == "Mississippi"|Province_State == "Missouri"|Province_State == "Montana"|Province_State == "Nebraska"|Province_State == "Nevada"|Province_State == "New Mexico"|Province_State == "North Dakota"|Province_State == "Northern Mariana Islands"|Province_State == "Ohio"|Province_State == "Oklahoma"|Province_State == "Pennsylvania"|Province_State == "Puerto Rico"|Province_State == "South Dakota"|Province_State == "Tennessee"|Province_State == "Texas"|Province_State == "Utah"|Province_State == "Iowa"|Province_State == "Virgin Islands"|Province_State == "West Virginia"|Province_State == "Wisconsin"|Province_State == "Wyoming")
data_mid_coast_day_2<-covid_data %>% filter(Last_Update>= "2021-03-14 05:31:09",Last_Update<"2021-03-15 05:31:06",Province_State == "Arizona"|Province_State == "Arkansas"|Province_State == "Colorado"|Province_State == "Diamond Princess"|Province_State == "District of Columbia"|Province_State == "Grand Princess"|Province_State == "Guam"|Province_State == "Idaho"|Province_State == "Illinois"|Province_State == "Indiana"|Province_State == "Iowa"|Province_State == "Kansas"|Province_State == "Kentucky"|Province_State == "Louisiana"|Province_State == "Michigan"|Province_State == "Minnesota"|Province_State == "Mississippi"|Province_State == "Missouri"|Province_State == "Montana"|Province_State == "Nebraska"|Province_State == "Nevada"|Province_State == "New Mexico"|Province_State == "North Dakota"|Province_State == "Northern Mariana Islands"|Province_State == "Ohio"|Province_State == "Oklahoma"|Province_State == "Pennsylvania"|Province_State == "Puerto Rico"|Province_State == "South Dakota"|Province_State == "Tennessee"|Province_State == "Texas"|Province_State == "Utah"|Province_State == "Iowa"|Province_State == "Virgin Islands"|Province_State == "West Virginia"|Province_State == "Wisconsin"|Province_State == "Wyoming")
data_mid_coast_day_3<-covid_data %>% filter(Last_Update>= "2021-03-15 05:31:06",Last_Update<"2021-03-16 05:31:04",Province_State == "Arizona"|Province_State == "Arkansas"|Province_State == "Colorado"|Province_State == "Diamond Princess"|Province_State == "District of Columbia"|Province_State == "Grand Princess"|Province_State == "Guam"|Province_State == "Idaho"|Province_State == "Illinois"|Province_State == "Indiana"|Province_State == "Iowa"|Province_State == "Kansas"|Province_State == "Kentucky"|Province_State == "Louisiana"|Province_State == "Michigan"|Province_State == "Minnesota"|Province_State == "Mississippi"|Province_State == "Missouri"|Province_State == "Montana"|Province_State == "Nebraska"|Province_State == "Nevada"|Province_State == "New Mexico"|Province_State == "North Dakota"|Province_State == "Northern Mariana Islands"|Province_State == "Ohio"|Province_State == "Oklahoma"|Province_State == "Pennsylvania"|Province_State == "Puerto Rico"|Province_State == "South Dakota"|Province_State == "Tennessee"|Province_State == "Texas"|Province_State == "Utah"|Province_State == "Iowa"|Province_State == "Virgin Islands"|Province_State == "West Virginia"|Province_State == "Wisconsin"|Province_State == "Wyoming")
data_mid_coast_day_4<-covid_data %>% filter(Last_Update>= "2021-03-16 05:31:04",Last_Update<"2021-03-17 05:31:00",Province_State == "Arizona"|Province_State == "Arkansas"|Province_State == "Colorado"|Province_State == "Diamond Princess"|Province_State == "District of Columbia"|Province_State == "Grand Princess"|Province_State == "Guam"|Province_State == "Idaho"|Province_State == "Illinois"|Province_State == "Indiana"|Province_State == "Iowa"|Province_State == "Kansas"|Province_State == "Kentucky"|Province_State == "Louisiana"|Province_State == "Michigan"|Province_State == "Minnesota"|Province_State == "Mississippi"|Province_State == "Missouri"|Province_State == "Montana"|Province_State == "Nebraska"|Province_State == "Nevada"|Province_State == "New Mexico"|Province_State == "North Dakota"|Province_State == "Northern Mariana Islands"|Province_State == "Ohio"|Province_State == "Oklahoma"|Province_State == "Pennsylvania"|Province_State == "Puerto Rico"|Province_State == "South Dakota"|Province_State == "Tennessee"|Province_State == "Texas"|Province_State == "Utah"|Province_State == "Iowa"|Province_State == "Virgin Islands"|Province_State == "West Virginia"|Province_State == "Wisconsin"|Province_State == "Wyoming")
data_mid_coast_day_5<-covid_data %>% filter(Last_Update>= "2021-03-17 05:31:00",Last_Update<"2021-03-18 05:31:01",Province_State == "Arizona"|Province_State == "Arkansas"|Province_State == "Colorado"|Province_State == "Diamond Princess"|Province_State == "District of Columbia"|Province_State == "Grand Princess"|Province_State == "Guam"|Province_State == "Idaho"|Province_State == "Illinois"|Province_State == "Indiana"|Province_State == "Iowa"|Province_State == "Kansas"|Province_State == "Kentucky"|Province_State == "Louisiana"|Province_State == "Michigan"|Province_State == "Minnesota"|Province_State == "Mississippi"|Province_State == "Missouri"|Province_State == "Montana"|Province_State == "Nebraska"|Province_State == "Nevada"|Province_State == "New Mexico"|Province_State == "North Dakota"|Province_State == "Northern Mariana Islands"|Province_State == "Ohio"|Province_State == "Oklahoma"|Province_State == "Pennsylvania"|Province_State == "Puerto Rico"|Province_State == "South Dakota"|Province_State == "Tennessee"|Province_State == "Texas"|Province_State == "Utah"|Province_State == "Iowa"|Province_State == "Virgin Islands"|Province_State == "West Virginia"|Province_State == "Wisconsin"|Province_State == "Wyoming")
data_mid_coast_day_6<-covid_data %>% filter(Last_Update>= "2021-03-18 05:31:01",Last_Update<"2021-03-19 05:30:59",Province_State == "Arizona"|Province_State == "Arkansas"|Province_State == "Colorado"|Province_State == "Diamond Princess"|Province_State == "District of Columbia"|Province_State == "Grand Princess"|Province_State == "Guam"|Province_State == "Idaho"|Province_State == "Illinois"|Province_State == "Indiana"|Province_State == "Iowa"|Province_State == "Kansas"|Province_State == "Kentucky"|Province_State == "Louisiana"|Province_State == "Michigan"|Province_State == "Minnesota"|Province_State == "Mississippi"|Province_State == "Missouri"|Province_State == "Montana"|Province_State == "Nebraska"|Province_State == "Nevada"|Province_State == "New Mexico"|Province_State == "North Dakota"|Province_State == "Northern Mariana Islands"|Province_State == "Ohio"|Province_State == "Oklahoma"|Province_State == "Pennsylvania"|Province_State == "Puerto Rico"|Province_State == "South Dakota"|Province_State == "Tennessee"|Province_State == "Texas"|Province_State == "Utah"|Province_State == "Iowa"|Province_State == "Virgin Islands"|Province_State == "West Virginia"|Province_State == "Wisconsin"|Province_State == "Wyoming")
data_mid_coast_day_7<-covid_data %>% filter(Last_Update>= "2021-03-19 05:30:59",Last_Update<"2021-03-20 05:31:09",Province_State == "Arizona"|Province_State == "Arkansas"|Province_State == "Colorado"|Province_State == "Diamond Princess"|Province_State == "District of Columbia"|Province_State == "Grand Princess"|Province_State == "Guam"|Province_State == "Idaho"|Province_State == "Illinois"|Province_State == "Indiana"|Province_State == "Iowa"|Province_State == "Kansas"|Province_State == "Kentucky"|Province_State == "Louisiana"|Province_State == "Michigan"|Province_State == "Minnesota"|Province_State == "Mississippi"|Province_State == "Missouri"|Province_State == "Montana"|Province_State == "Nebraska"|Province_State == "Nevada"|Province_State == "New Mexico"|Province_State == "North Dakota"|Province_State == "Northern Mariana Islands"|Province_State == "Ohio"|Province_State == "Oklahoma"|Province_State == "Pennsylvania"|Province_State == "Puerto Rico"|Province_State == "South Dakota"|Province_State == "Tennessee"|Province_State == "Texas"|Province_State == "Utah"|Province_State == "Iowa"|Province_State == "Virgin Islands"|Province_State == "West Virginia"|Province_State == "Wisconsin"|Province_State == "Wyoming")
data_mid_day_1_2 <- rbind(data_mid_coast_day_1, data_mid_coast_day_2)
data_mid_day_3_4 <- rbind(data_mid_coast_day_3, data_mid_coast_day_4)
data_mid_day_5_6 <- rbind(data_mid_coast_day_5, data_mid_coast_day_6)
data_mid_day_1half <- rbind(data_mid_day_1_2, data_mid_day_3_4)
data_mid_day_2half <- rbind(data_mid_day_5_6, data_mid_coast_day_7)
covid_data_mid <- rbind(data_mid_day_1half, data_mid_day_2half)
glimpse(covid_data_mid)

covid_data_mid
# Out:
# Observations: 252
# Variables: 18
# $ Province_State       <chr> "Arizona", "Arkansas", "Colorado", "Diamond Pr...
# $ Country_Region       <chr> "US", "US", "US", "US", "US", "US", "US", "US"...
# $ Last_Update          <dttm> 2021-03-14 05:31:09, 2021-03-14 05:31:09, 202...
# $ Lat                  <dbl> 33.7298, 34.9697, 39.0598, NA, 38.8974, NA, 13...
# $ Long_                <dbl> -111.4312, -92.3731, -105.3111, NA, -77.0268, ...
# $ Confirmed            <dbl> 832094, 326813, 442753, 49, 42432, 103, 7768, ...
# $ Deaths               <dbl> 16546, 5455, 6036, 0, 1040, 3, 133, 1910, 2318...
# $ Recovered            <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA...
# $ Active               <lgl> NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA, NA...
# $ FIPS                 <dbl> 4, 5, 8, 88888, 11, 99999, 66, 16, 17, 18, 19,...
# $ Incident_Rate        <dbl> 11431.8773, 10829.4972, 7688.3712, NA, 6012.33...
# ...

# %%
covid_data$Last_Update <- as.Date(covid_data$Last_Update)
# Trim down the time for consistency


covid_data_dailySum <- covid_data %>%
    group_by(Last_Update) %>% 
    summarise(Total_Confirmed = sum(Confirmed), Deaths = sum(Deaths), Mean_CFRatio = mean(Case_Fatality_Ratio, na.rm=TRUE))


covid_data_dailySum$type <-  covid_data_dailySum$Deaths / covid_data_dailySum$Deaths
covid_data_dailySum
# Out:
#   Last_Update Total_Confirmed Deaths Mean_CFRatio type
# 1 2021-03-14  29400553        534316 1.688361     1
# 2 2021-03-15  29438775        534888 1.686309     1
# 3 2021-03-16  29495424        535628 1.684618     1
# 4 2021-03-17  29549235        536914 1.684908     1
# 5 2021-03-18  29608206        538087 1.684693     1
# 6 2021-03-19  29668587        539698 1.685608     1
# 7 2021-03-20  29730000        541143 1.685500     1

# %%
covid_data_east$Last_Update <- as.Date(covid_data_east$Last_Update)
# Trim down the time for consistency


covid_data_dailySum_east <- covid_data_east %>%
    group_by(Last_Update) %>% 
    summarise(Total_Confirmed = sum(Confirmed), Deaths = sum(Deaths), Mean_CFRatio = mean(Case_Fatality_Ratio, na.rm=TRUE))

covid_data_dailySum_east$type <-  covid_data_dailySum_east$Deaths / covid_data_dailySum_east$Deaths*2
covid_data_dailySum_east
# Out:
#   Last_Update Total_Confirmed Deaths Mean_CFRatio type
# 1 2021-03-14  9213739         192136 1.996027     2
# 2 2021-03-15  9233545         192366 1.993630     2
# 3 2021-03-16  9258579         192725 1.990536     2
# 4 2021-03-17  9282146         193110 1.989141     2
# 5 2021-03-18  9308557         193592 1.987810     2
# 6 2021-03-19  9336897         193998 1.985054     2
# 7 2021-03-20  9363803         194241 1.981273     2

# %%
covid_data_west$Last_Update <- as.Date(covid_data_west$Last_Update)
# Trim down the time for consistency


covid_data_dailySum_west <- covid_data_west %>%
    group_by(Last_Update) %>% 
    summarise(Total_Confirmed = sum(Confirmed), Deaths = sum(Deaths), Mean_CFRatio = mean(Case_Fatality_Ratio, na.rm=TRUE))

covid_data_dailySum_west$type <-  covid_data_dailySum_west$Deaths / covid_data_dailySum_west$Deaths*3
covid_data_dailySum_west
# Out:
#   Last_Update Total_Confirmed Deaths Mean_CFRatio type
# 1 2021-03-14  4218428         64626  1.312926     3
# 2 2021-03-15  4220866         64774  1.313306     3
# 3 2021-03-16  4225512         64889  1.312195     3
# 4 2021-03-17  4228665         65047  1.314591     3
# 5 2021-03-18  4233193         65249  1.314277     3
# 6 2021-03-19  4238150         65481  1.314764     3
# 7 2021-03-20  4242562         65642  1.313518     3

# %%
covid_data_mid$Last_Update <- as.Date(covid_data_mid$Last_Update)
# Trim down the time for consistency


covid_data_dailySum_mid <- covid_data_mid %>%
    group_by(Last_Update) %>% 
    summarise(Total_Confirmed = sum(Confirmed), Deaths = sum(Deaths), Mean_CFRatio = mean(Case_Fatality_Ratio, na.rm=TRUE))

covid_data_dailySum_mid$type <-  covid_data_dailySum_mid$Deaths / covid_data_dailySum_mid$Deaths*4
covid_data_dailySum_mid
# Out:
#   Last_Update Total_Confirmed Deaths Mean_CFRatio type
# 1 2021-03-14  15448383        267013 1.622060     4
# 2 2021-03-15  15463801        267207 1.620137     4
# 3 2021-03-16  15486112        267471 1.619527     4
# 4 2021-03-17  15512660        268205 1.620156     4
# 5 2021-03-18  15539874        268666 1.620116     4
# 6 2021-03-19  15566245        269611 1.622768     4
# 7 2021-03-20  15595663        270618 1.624407     4

# %%
covid_final<-do.call("rbind", list(covid_data_dailySum, covid_data_dailySum_east, covid_data_dailySum_west,covid_data_dailySum_mid))
covid_final
# Out:
#    Last_Update Total_Confirmed Deaths Mean_CFRatio type
# 1  2021-03-14  29400553        534316 1.688361     1
# 2  2021-03-15  29438775        534888 1.686309     1
# 3  2021-03-16  29495424        535628 1.684618     1
# 4  2021-03-17  29549235        536914 1.684908     1
# 5  2021-03-18  29608206        538087 1.684693     1
# 6  2021-03-19  29668587        539698 1.685608     1
# 7  2021-03-20  29730000        541143 1.685500     1
# 8  2021-03-14   9213739        192136 1.996027     2
# 9  2021-03-15   9233545        192366 1.993630     2
# 10 2021-03-16   9258579        192725 1.990536     2
# 11 2021-03-17   9282146        193110 1.989141     2
# 12 2021-03-18   9308557        193592 1.987810     2
# 13 2021-03-19   9336897        193998 1.985054     2
# 14 2021-03-20   9363803        194241 1.981273     2
# 15 2021-03-14   4218428         64626 1.312926     3
# 16 2021-03-15   4220866         64774 1.313306     3
# 17 2021-03-16   4225512         64889 1.312195     3
# ...

# %%
library(ggplot2)
library(readxl)
library(tidyverse)
library(gganimate)
library(ggthemes)

plot<-covid_data%>% 
ggplot(aes(x=Last_Update,y=Confirmed, color=Province_State))+
geom_line(alpha=0.8) + geom_point(size=2)

# plot<-covid_data%>%
#   ggplot(aes(x=Last_Update,y=Confirmed,color=Province_State))+
#   geom_line(alpha=0.8)+
#   theme_solarized_2(light=F)+
#   labs(title="US COVID, 2021 MARCH 14 - 20",
#        caption="Source: ")+
#   theme(text=element_text(colour="#EEEEEE"),
#         title=element_text(colour="#EEEEEE",size=9,face = "bold"),
#         plot.title=element_text(hjust=0.5),
#         axis.title.x = element_blank(),
#         panel.grid.minor.x=element_blank(),
#         legend.background = element_blank(),
#         legend.key= element_blank(),
#         legend.position=c(0.095, 0.81), ## legend at top-left, inside the plot
#         plot.margin = unit(c(1,1,1,1), "cm"))
#  scale_x_date(date_labels = "%b",date_breaks ="Last_Update")


plot.animation=plot+
  transition_reveal(Last_Update)+
  view_follow(fixed_y=T)
#  height=365,width=608,fps=30,duration=10,end_pause = 120,res=100,rewind=F
animate(plot.animation,height=365,width=608,fps=60,duration=10,end_pause = 120,res=100,rewind=F)
anim_save("THE OFFICIAL EXCHANGE RATE OF THE HRYVNIA TO FOREIGN CURRENCIES.gif")
